# %% [markdown]
# # Install Library

# %%
# %pip install numpy
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
import re

# %% [markdown]
# # Read CSV

# %%
books = pd.read_csv("data/books_db.csv", encoding='utf-8')
books.head(2)
# Out:
#    id                book_title                 pushlisher  \
# 0   0  Assistant to the Villain  Entangled Publishing, LLC
# 1   1  My Roommate Is a Vampire   Penguin Publishing Group
#
#                   author   price  \
# 0  Hannah Nicole Maehrer  $19.99
# 1           Jenna Levine  $15.30
#
#                                             category  rating  \
# 0  ['Comic Fantasy', 'Fantasy Romance', 'Science ...     4.8
# 1  ['Humorous Contemporary Romance', 'Vampire Rom...     4.1
#
#                                               images  \
# 0  {'https://prodimage.images-bn.com/lf?set=key%5...
# 1  {'https://prodimage.images-bn.com/lf?set=key%5...
#
#                                                 desc publication_date   page  \
# 0  <br/><div class="bs-content content-spacing"><...       08/29/2023  352.0
# 1  <br/><div class="bs-content content-spacing"><...       08/29/2023  352.0
#
#              product_dimensions  rating_count  \
# ...

# %% [markdown]
# # Data

# %%
books_clean = []
for book in books["desc"].values:
    regx = re.findall(">(.*?)<", book)
    clean = "".join(regx).replace("Notes From Your Bookseller","").strip()
    books_clean.append(clean)
books["desc"]=books_clean
books
# Out:
#         id                                         book_title  \
# 0        0                           Assistant to the Villain
# 1        1                           My Roommate Is a Vampire
# 2        2                                        23 1/2 Lies
# 3        3                                 Godkiller: A Novel
# 4        4                                You, Again: A Novel
# ...    ...                                                ...
# 1987  1987                               I am Jackie Robinson
# 1988  1988                   Dark Corners of the Old Dominion
# 1989  1989                  Seven Summers (And a Few Bummers)
# 1990  1990  Reframe Your Brain: The User Interface for Hap...
# 1991  1991       The Knight Blooms Behind Castle Walls Vol. 3
#
#                          pushlisher                   author   price  \
# 0         Entangled Publishing, LLC    Hannah Nicole Maehrer  $19.99
# 1          Penguin Publishing Group             Jenna Levine  $15.30
# ...

# %%
reviews.to_csv("data/reviews.csv", sep=',', index=False, encoding='utf-8', index_label=None)
