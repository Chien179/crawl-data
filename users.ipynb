# %% [markdown]
# # Install Library

# %%
# %pip install numpy
# %pip install pandas
# %pip install bcrypt
# Out:
# Requirement already satisfied: numpy in ./venv/lib/python3.10/site-packages (1.26.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in ./venv/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: tzdata>=2022.1 in ./venv/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy<2,>=1.22.4 in ./venv/lib/python3.10/site-packages (from pandas) (1.26.1)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: bcrypt in ./venv/lib/python3.10/site-packages (4.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
import csv
from datetime import datetime
from random import randint, choice
import bcrypt

# %% [markdown]
# # Functions

# %%
def get_username(name):
    return name+str(randint(100, 100000))

# %%
def get_phone_number() -> str:
    phone_header = ['86','96','97','98','32','33','34','35','36','37','38','39','88','91','94','83','84','85','81','82','89','90','93','70','79','77','76','78','92','56','58','99','59']
    return '+84'+str(choice(phone_header))+str(randint(1000000,9999999))

# %%
def get_age():
    return randint(12,60)

# %%
def get_email(name):
    return name+str(randint(000, 999))+'@gmail.com'

# %%
def hash_password():
    # example password
    password = "123456789"

    # converting password to array of bytes
    bytes = password.encode("utf-8")

    # generating the salt
    salt = bcrypt.gensalt()

    # Hashing the password
    hash = bcrypt.hashpw(bytes, salt).decode("utf-8")

    return hash

# %% [markdown]
# # Read CSV

# %%
df_male = pd.read_csv("data_raw/male.csv", encoding='utf-8')
len_rows = df_male.shape[0]
df_male['username'] = [get_username(i) for i in df_male['full_name']]
df_male['email'] = [get_email(i) for i in df_male['full_name']]
df_male['password'] = [hash_password() for _ in range(len_rows)]
df_male['phone_number'] = [get_phone_number() for _ in range(len_rows)]
df_male['age'] = [get_age() for _ in range(len_rows)]
df_male['sex'] = [1]*len_rows
df_male['image'] = ['https://res.cloudinary.com/doqhasjec/image/upload/v1681990980/samples/NMC%20Bookstore/Default_ct9xzk.png?fbclid=IwAR1-YjqZGj-wZzoRzdaUFg581OdLLb-3Epm7vlJF_vnCty5K-UJre4iYTpY'] * len_rows
df_male
# Out:
#     full_name       username                  email  \
# 0       James     James39476     James702@gmail.com
# 1        John      John76888       John90@gmail.com
# 2      Robert    Robert74192     Robert74@gmail.com
# 3     Michael    Michael6704   Michael885@gmail.com
# 4     William   William60414     William5@gmail.com
# ..        ...            ...                    ...
# 295   Eduardo     Eduardo227   Eduardo987@gmail.com
# 296  Terrence  Terrence46426  Terrence763@gmail.com
# 297   Enrique   Enrique10284   Enrique815@gmail.com
# 298   Freddie   Freddie24902   Freddie198@gmail.com
# 299      Wade      Wade80549      Wade286@gmail.com
#
#                                               password  phone_number  age  \
# 0    $2b$12$Y3VgodP5oq0PIe45.Ys/TuCMtdvaWfu441MLOHQ...  +84835249688   55
# 1    $2b$12$/YvcL7ZSv9bsGAG4y7Dc5OxhSUZgfsHPMh.O5KF...  +84962119385   25
# 2    $2b$12$K3ntdnNUpNWdf4lwfIhBzuodX8.Ht9lwkO7fD8P...  +84344089708   22
# 3    $2b$12$r1r01VapW98T1CaMF1LRGeUrVuo6xZNDOhOpk30...  +84979205166   22
# 4    $2b$12$DEfcKn5AYlj.oZWLdIaeq.9HminDT2M3mJEjElm...  +84789926347   36
# ..                                                 ...           ...  ...
# 295  $2b$12$CKpzjsu16n8c4.DwyxnhJexp2HJZ0b1p.gHJYzd...  +84593344895   48
# 296  $2b$12$WsPxEOTQBUyGkX070.A92OM7YUuqqxlh05waPY7...  +84916470461   36
# 297  $2b$12$FGhknDHoKp6qsf2ZsRjod.D8mI8otjVa8AIQr1....  +84363339133   60
# 298  $2b$12$.sSz44nlckt5qHqsx9bhkOkYjlBvJFQNMLkBwIv...  +84861449924   39
# 299  $2b$12$.Bh0r.H6bPqeMLescT3OYOGbqXWdsnpx8lR2jB1...  +84997055912   35
#
#      sex                                              image
# 0      1  https://res.cloudinary.com/doqhasjec/image/upl...
# 1      1  https://res.cloudinary.com/doqhasjec/image/upl...
# 2      1  https://res.cloudinary.com/doqhasjec/image/upl...
# 3      1  https://res.cloudinary.com/doqhasjec/image/upl...
# 4      1  https://res.cloudinary.com/doqhasjec/image/upl...
# ..   ...                                                ...
# 295    1  https://res.cloudinary.com/doqhasjec/image/upl...
# 296    1  https://res.cloudinary.com/doqhasjec/image/upl...
# 297    1  https://res.cloudinary.com/doqhasjec/image/upl...
# 298    1  https://res.cloudinary.com/doqhasjec/image/upl...
# 299    1  https://res.cloudinary.com/doqhasjec/image/upl...
#
# [300 rows x 8 columns]

# %%
df_female = pd.read_csv("data_raw/female.csv", encoding='utf-8')
len_rows = df_female.shape[0]
df_female['username'] = [get_username(i) for i in df_female['full_name']]
df_female['email'] = [get_email(i) for i in df_female['full_name']]
df_female['password'] = [hash_password() for _ in range(len_rows)]
df_female['phone_number'] = [get_phone_number() for _ in range(len_rows)]
df_female['age'] = [get_age() for _ in range(len_rows)]
df_female['sex'] = [0]*len_rows
df_female['image'] = ['https://res.cloudinary.com/doqhasjec/image/upload/v1681990980/samples/NMC%20Bookstore/Default_ct9xzk.png?fbclid=IwAR1-YjqZGj-wZzoRzdaUFg581OdLLb-3Epm7vlJF_vnCty5K-UJre4iYTpY'] * len_rows
df_female
# Out:
#      full_name        username                   email  \
# 0         Mary       Mary13409       Mary445@gmail.com
# 1     Patricia    Patricia9353   Patricia925@gmail.com
# 2        Linda      Linda74415      Linda707@gmail.com
# 3      Barbara    Barbara93016    Barbara333@gmail.com
# 4    Elizabeth  Elizabeth18044  Elizabeth377@gmail.com
# ..         ...             ...                     ...
# 295     Ramona     Ramona40871     Ramona313@gmail.com
# 296     Sherri     Sherri13762     Sherri559@gmail.com
# 297      Erika      Erika60893      Erika558@gmail.com
# 298    Katrina    Katrina73768    Katrina855@gmail.com
# 299     Claire      Claire1682     Claire782@gmail.com
#
#                                               password  phone_number  age  \
# 0    $2b$12$5ygoFy2yuys3jgtHaVGy..KbRJ6GjTVWuD9/4YO...  +84564659817   49
# 1    $2b$12$jHTpGH3BIROBdzltGluY8.1VVrYiZog72V2VVEq...  +84968941750   13
# 2    $2b$12$n8ACrG2sKHmUB3MEBCKVWeNhxeM1JLAJWpj0Ju1...  +84891043282   12
# 3    $2b$12$LbxAsiipT7JfqhTwNDLWo.vNs1wS/wCjZNUjz5h...  +84985086136   34
# 4    $2b$12$dgCMQwvGpysx/ba.K46JNu8FGGYJIKr3j2NP8EL...  +84374864973   24
# ..                                                 ...           ...  ...
# 295  $2b$12$a5sDJhsvJrCtagLAXDUDwu6PzQ9g2txaaEZb6aC...  +84322369827   32
# 296  $2b$12$akk8ZUGEwhXhyWPYYREok.rAuhvW8nwvk.TlYMK...  +84344463915   27
# 297  $2b$12$ngVTi8HOHTyIIOQHppYWpOWwfDGrvFanjqZME9U...  +84911612697   56
# 298  $2b$12$w7CzLOGK1VDYx3rjCCbd5uGhUzpxUweDX31e9g8...  +84368033578   38
# 299  $2b$12$ga4uPWOmK0NfHeYFhEEPiO.0ivv5Kpz8rC6AzMR...  +84995851043   29
#
#      sex                                              image
# 0      0  https://res.cloudinary.com/doqhasjec/image/upl...
# 1      0  https://res.cloudinary.com/doqhasjec/image/upl...
# 2      0  https://res.cloudinary.com/doqhasjec/image/upl...
# 3      0  https://res.cloudinary.com/doqhasjec/image/upl...
# 4      0  https://res.cloudinary.com/doqhasjec/image/upl...
# ..   ...                                                ...
# 295    0  https://res.cloudinary.com/doqhasjec/image/upl...
# 296    0  https://res.cloudinary.com/doqhasjec/image/upl...
# 297    0  https://res.cloudinary.com/doqhasjec/image/upl...
# 298    0  https://res.cloudinary.com/doqhasjec/image/upl...
# 299    0  https://res.cloudinary.com/doqhasjec/image/upl...
#
# [300 rows x 8 columns]

# %% [markdown]
# # Data

# %%
columns = ['username','full_name', 'email', 'password', 'image', 'phone_number', 'age', 'sex']
df_male = df_male[columns]
df_female = df_female[columns]
df = pd.concat([df_male, df_female])
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#          username full_name                 email  \
# 0     Dwight21717    Dwight   Dwight584@gmail.com
# 1    Lillian19125   Lillian  Lillian472@gmail.com
# 2        Dean8263      Dean     Dean865@gmail.com
# 3       Dana27654      Dana     Dana229@gmail.com
# 4     Leslie99748    Leslie   Leslie789@gmail.com
# ..            ...       ...                   ...
# 595    Victor5488    Victor   Victor969@gmail.com
# 596    Isaac99095     Isaac    Isaac339@gmail.com
# 597   Calvin17499    Calvin     Calvin2@gmail.com
# 598  Clifton53100   Clifton  Clifton807@gmail.com
# 599    Norma41737     Norma    Norma853@gmail.com
#
#                                               password  \
# 0    $2b$12$y/qLtInTc6/2Jt49HWMzRu8oMNqYriuVFjvRkxF...
# 1    $2b$12$pJu5zruLscg68N8uTZyDTOqAlFXeFooaH6AJjJK...
# 2    $2b$12$dL0pOAk1mpeA0/8893y76eeOpYNGGwNXM/GKUAw...
# 3    $2b$12$hZ6fU2JcLrn/g5oabam0yOOrmYXvD495IEmZJFe...
# 4    $2b$12$zE4PtQKaMjuXLVaEI.UJZuh600nL48acQ9XJk9B...
# ..                                                 ...
# 595  $2b$12$2gCv505uvoLjdoJI6kzbcOQ3r723/9VRCDWFWZf...
# 596  $2b$12$LOUUZ5B0mxnubSNdJL236ulqv0ZJdpJlFumRi64...
# 597  $2b$12$j3t9ct1C/BwSQkMdsHpbC.88ijIlLzj2iyHaNsq...
# 598  $2b$12$UdwRFiTKSKWybMxmOttdnOERisicMyyCAEyWnee...
# 599  $2b$12$uL0qPCTli2NZPEzMEZpd2.0053UFEr0eHEnKRZV...
#
#                                                  image  phone_number  age  sex
# 0    https://res.cloudinary.com/doqhasjec/image/upl...  +84994097457   21    1
# 1    https://res.cloudinary.com/doqhasjec/image/upl...  +84376000638   45    0
# 2    https://res.cloudinary.com/doqhasjec/image/upl...  +84882811741   26    1
# 3    https://res.cloudinary.com/doqhasjec/image/upl...  +84327686991   40    0
# 4    https://res.cloudinary.com/doqhasjec/image/upl...  +84327525713   51    1
# ..                                                 ...           ...  ...  ...
# 595  https://res.cloudinary.com/doqhasjec/image/upl...  +84859583328   35    1
# 596  https://res.cloudinary.com/doqhasjec/image/upl...  +84985344885   14    1
# 597  https://res.cloudinary.com/doqhasjec/image/upl...  +84894029959   39    1
# 598  https://res.cloudinary.com/doqhasjec/image/upl...  +84325847901   28    1
# 599  https://res.cloudinary.com/doqhasjec/image/upl...  +84352203333   12    0
#
# [600 rows x 8 columns]

# %%
df.to_csv("data_raw/users.csv", sep=',', index=False, encoding='utf-8', index_label=None)
